# %%
#import pandas module
import pandas as pd

# %%
#create path for files
csv1_path = "./Resources/JC-201901-citibike-tripdata.csv/JC-201901-citibike-tripdata.csv"
bike_data = pd.read_csv(csv1_path)
bike_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19671           853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
# 19672           936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
# 19673           653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
# 19674           960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
# 19675          1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
#        start station id start station name  start station latitude  \
# 0                  3183     Exchange Place               40.716247
# 1                  3183     Exchange Place               40.716247
# 2                  3183     Exchange Place               40.716247
# 3                  3183     Exchange Place               40.716247
# 4                  3183     Exchange Place               40.716247
# ...                 ...                ...                     ...
# 19671              3694     Jackson Square               40.711130
# 19672              3694     Jackson Square               40.711130
# 19673              3694     Jackson Square               40.711130
# 19674              3694     Jackson Square               40.711130
# 19675              3694     Jackson Square               40.711130
#
#        start station longitude  end station id    end station name  \
# 0                   -74.033459            3214    Essex Light Rail
# 1                   -74.033459            3638       Washington St
# 2                   -74.033459            3192  Liberty Light Rail
# 3                   -74.033459            3638       Washington St
# 4                   -74.033459            3638       Washington St
# ...                        ...             ...                 ...
# 19671               -74.078900            3183      Exchange Place
# 19672               -74.078900            3183      Exchange Place
# 19673               -74.078900            3677        Glenwood Ave
# 19674               -74.078900            3183      Exchange Place
# 19675               -74.078900            3183      Exchange Place
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.712774             -74.036486   29612  Subscriber
# 1                 40.724294             -74.035483   29213  Subscriber
# 2                 40.711242             -74.055701   26164  Subscriber
# 3                 40.724294             -74.035483   29672    Customer
# 4                 40.724294             -74.035483   29522    Customer
# ...                     ...                    ...     ...         ...
# 19671             40.716247             -74.033459   26293  Subscriber
# 19672             40.716247             -74.033459   26291  Subscriber
# 19673             40.727551             -74.071061   26188    Customer
# 19674             40.716247             -74.033459   26196  Subscriber
# 19675             40.716247             -74.033459   26242  Subscriber
#
#        birth year  gender
# 0            1993       1
# 1            1972       2
# 2            1985       1
# 3            1969       0
# 4            1969       0
# ...           ...     ...
# 19671        1977       1
# 19672        1977       1
# 19673        1998       2
# 19674        1977       1
# 19675        1977       1
#
# [19676 rows x 15 columns]

# %%
for x in range(2, 13):
   
    if (x == 10):
        file = f"JC-2019{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data = bike_data.append(bike_loop, ignore_index=True)
    elif (x == 11):
        file = f"JC-2019{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data = bike_data.append(bike_loop, ignore_index=True)
    elif (x == 12):
        file = f"JC-2019{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data = bike_data.append(bike_loop, ignore_index=True)
    else:
        file = f"JC-20190{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data = bike_data.append(bike_loop, ignore_index=True)
bike_data
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3               1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4               1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...              ...                       ...                       ...
# 790213           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 790214           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 790215           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 790216           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 790217           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#         start station id start station name  start station latitude  \
# 0                   3183     Exchange Place               40.716247
# 1                   3183     Exchange Place               40.716247
# 2                   3183     Exchange Place               40.716247
# 3                   3183     Exchange Place               40.716247
# 4                   3183     Exchange Place               40.716247
# ...                  ...                ...                     ...
# 790213              3195            Sip Ave               40.730897
# 790214              3186      Grove St PATH               40.719586
# 790215              3209       Brunswick St               40.724176
# 790216              3639         Harborside               40.719252
# 790217              3195            Sip Ave               40.730897
#
#         start station longitude  end station id    end station name  \
# 0                    -74.033459            3214    Essex Light Rail
# 1                    -74.033459            3638       Washington St
# 2                    -74.033459            3192  Liberty Light Rail
# 3                    -74.033459            3638       Washington St
# 4                    -74.033459            3638       Washington St
# ...                         ...             ...                 ...
# 790213               -74.063913            3679          Bergen Ave
# 790214               -74.043117            3205   JC Medical Center
# 790215               -74.050656            3185           City Hall
# 790216               -74.034234            3186       Grove St PATH
# 790217               -74.063913            3280         Astor Place
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  40.712774             -74.036486   29612  Subscriber
# 1                  40.724294             -74.035483   29213  Subscriber
# 2                  40.711242             -74.055701   26164  Subscriber
# 3                  40.724294             -74.035483   29672    Customer
# 4                  40.724294             -74.035483   29522    Customer
# ...                      ...                    ...     ...         ...
# 790213             40.722104             -74.071455   29245    Customer
# 790214             40.716540             -74.049638   26153  Subscriber
# 790215             40.717732             -74.043845   26276  Subscriber
# 790216             40.719586             -74.043117   29461  Subscriber
# 790217             40.719282             -74.071262   29123  Subscriber
#
#         birth year  gender
# 0             1993       1
# 1             1972       2
# 2             1985       1
# 3             1969       0
# 4             1969       0
# ...            ...     ...
# 790213        1990       1
# 790214        1989       1
# 790215        1984       1
# 790216        1987       1
# 790217        1988       1
#
# [790218 rows x 15 columns]

# %%
output_data_file1 = "./Resources/JC-2019-citibike-tripdata.csv"
bike_data2.to_csv(output_data_file1, index_label = "Bike ID")

# %%
#create path for files
csv2_path = "./Resources/JC-202001-citibike-tripdata.csv/JC-202001-citibike-tripdata.csv"
bike_data2 = pd.read_csv(csv2_path)
bike_data2
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# 0                  3186               Grove St PATH               40.719586
# 1                  3186               Grove St PATH               40.719586
# 2                  3186               Grove St PATH               40.719586
# 3                  3195                     Sip Ave               40.730897
# 4                  3186               Grove St PATH               40.719586
# ...                 ...                         ...                     ...
# 26015              3213              Van Vorst Park               40.718489
# 26016              3792  Columbus Dr at Exchange Pl               40.716870
# 26017              3273                Manila & 1st               40.721651
# 26018              3185                   City Hall               40.717732
# 26019              3206                     Hilltop               40.731169
#
#        start station longitude  end station id  end station name  \
# 0                   -74.043117            3211        Newark Ave
# 1                   -74.043117            3269   Brunswick & 6th
# 2                   -74.043117            3269   Brunswick & 6th
# 3                   -74.063913            3280       Astor Place
# 4                   -74.043117            3276  Marin Light Rail
# ...                        ...             ...               ...
# 26015               -74.047727            3194   McGinley Square
# 26016               -74.032810            3639        Harborside
# 26017               -74.042884            3209      Brunswick St
# 26018               -74.043845            3267      Morris Canal
# 26019               -74.057574            3202      Newport PATH
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.721525             -74.046305   29444  Subscriber
# 1                 40.726012             -74.050389   26305  Subscriber
# 2                 40.726012             -74.050389   29268    Customer
# 3                 40.719282             -74.071262   29278    Customer
# 4                 40.714584             -74.042817   29276  Subscriber
# ...                     ...                    ...     ...         ...
# 26015             40.725340             -74.067622   29659  Subscriber
# 26016             40.719252             -74.034234   42361  Subscriber
# 26017             40.724176             -74.050656   42368  Subscriber
# 26018             40.712419             -74.038526   42257  Subscriber
# 26019             40.727224             -74.033759   29302    Customer
#
#        birth year  gender
# 0            1984       2
# 1            1989       2
# 2            1989       1
# 3            1969       0
# 4            1983       2
# ...           ...     ...
# 26015        1989       1
# 26016        1991       1
# 26017        1988       1
# 26018        1981       2
# 26019        1998       1
#
# [26020 rows x 15 columns]

# %%
for x in range(2, 13):
   
    if (x == 10):
        file = f"JC-2020{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data2 = bike_data2.append(bike_loop, ignore_index=True)
    elif (x == 11):
        file = f"JC-2020{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data2 = bike_data2.append(bike_loop, ignore_index=True)
    elif (x == 12):
        file = f"JC-2020{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data2 = bike_data2.append(bike_loop, ignore_index=True)
    else:
        file = f"JC-20200{x}-citibike-tripdata.csv"
        path = f"./Resources/{file}/{file}"
        bike_loop = pd.read_csv(path)
        bike_data2 = bike_data2.append(bike_loop, ignore_index=True)
bike_data2
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# 0                   3186      Grove St PATH               40.719586
# 1                   3186      Grove St PATH               40.719586
# 2                   3186      Grove St PATH               40.719586
# 3                   3195            Sip Ave               40.730897
# 4                   3186      Grove St PATH               40.719586
# ...                  ...                ...                     ...
# 336797              3199       Newport Pkwy               40.728745
# 336798              3184        Paulus Hook               40.714145
# 336799              3195            Sip Ave               40.730897
# 336800              3681           Grand St               40.715178
# 336801              3267       Morris Canal               40.712419
#
#         start station longitude  end station id  end station name  \
# 0                    -74.043117            3211        Newark Ave
# 1                    -74.043117            3269   Brunswick & 6th
# 2                    -74.043117            3269   Brunswick & 6th
# 3                    -74.063913            3280       Astor Place
# 4                    -74.043117            3276  Marin Light Rail
# ...                         ...             ...               ...
# 336797               -74.032108            3199      Newport Pkwy
# 336798               -74.033552            3195           Sip Ave
# 336799               -74.063913            3270   Jersey & 6th St
# 336800               -74.037683            3199      Newport Pkwy
# 336801               -74.038526            3267      Morris Canal
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  40.721525             -74.046305   29444  Subscriber
# 1                  40.726012             -74.050389   26305  Subscriber
# 2                  40.726012             -74.050389   29268    Customer
# 3                  40.719282             -74.071262   29278    Customer
# 4                  40.714584             -74.042817   29276  Subscriber
# ...                      ...                    ...     ...         ...
# 336797             40.728745             -74.032108   40440    Customer
# 336798             40.730897             -74.063913   46340    Customer
# 336799             40.725289             -74.045572   40907    Customer
# 336800             40.728745             -74.032108   42250    Customer
# 336801             40.712419             -74.038526   48742  Subscriber
#
#         birth year  gender
# 0             1984       2
# 1             1989       2
# 2             1989       1
# 3             1969       0
# 4             1983       2
# ...            ...     ...
# 336797        1969       0
# 336798        1969       0
# 336799        1998       1
# 336800        1969       0
# 336801        1982       1
#
# [336802 rows x 15 columns]

# %%
output_data_file2 = "./Resources/JC-2020-citibike-tripdata.csv"
bike_data2.to_csv(output_data_file2, index_label = "Bike ID")
